# %% [markdown]
# # Les arbres de classification

# %% [markdown]
# ## Chargement des données

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
myData = pd.read_csv("titanic.csv")
print(myData.head())
# Out:
#    id      class     age  sex survived
# 0   1  1st class  adults  man      yes
# 1   2  1st class  adults  man      yes
# 2   3  1st class  adults  man      yes
# 3   4  1st class  adults  man      yes
# 4   5  1st class  adults  man      yes

# %% [markdown]
# **Questions**:
# - a) Commentez les données.
# - b) Supprimez la variable *id* qui n'est pas une donnée exploitable.
# - c) Quelles sont les variables binaires et quelles sont les variables à plus de deux modalités ?
#      Utilisez la fonction `describe()` pour répondre à cette question.
